# %%
import pandas as pd
import numpy as np 
import json
import seaborn as sn
import matplotlib.pyplot as plt
from pylab import * 
import networkx as nx

# %% [markdown]
# ## Read in Data

# %%
df = pd.read_json('yelp_bizdata.json', lines=True) # business data 
df = df.rename(columns={'business_id': 'Business'})
dfuser = pd.read_json('yelp_userdata.json', lines=True)
dfuser = dfuser.rename(columns={'user_id': 'User'})
dfrev = pd.read_json('yelpreviews.json', lines=True)

# %%
dfrev
# Out:
#                       review_id                 user_id  \
# 0        lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw
# 1        8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg
# 2        NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw
# 3        T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA
# 4        sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A
# ...                         ...                     ...
# 2546944  CNfG18etDobCn-LlyH3TtQ  s6ZuqZLSlKvVZElSEd03Gw
# 2546945  uxIlS76PxfWxBZt4LgvZFg  caiSZUruSw1fkVOHtlS4kw
# 2546946  OAG58lQj7cWVT57M81oCDg  Jax59T2jZ5qrMwB4MmxChw
# 2546947  mdk2z1NasChYZf3ztlnwFA  _vpRHhJxPnse-xEt7tKb3A
# 2546948  mFhTJpR_vQKdvBS9NgXj0Q  UR1Vd8oFXfxunpBCuuPJ5Q
#
#                     business_id  stars  useful  funny  cool  \
# 0        buF9druCkbuXLX526sGELQ      4       3      1     1
# 1        RA4V8pr014UyUbDvI-LW2A      4       1      0     0
# 2        _sS2LBIGNT5NQb6PD1Vtjw      5       0      0     0
# 3        0AzLzHfOJgL7ROwhdww2ew      2       1      1     1
# 4        8zehGz9jnxPqXtOc7KaJxA      4       0      0     0
# ...                         ...    ...     ...    ...   ...
# 2546944  sB9dNoHtrJ6YDU1ynz4lcg      5       0      0     0
# 2546945  U65ez9BbaXyqKrqI1Atviw      3       0      0     0
# 2546946  0fWr9Ty_EGvimZ4h6Rw2yg      3       0      0     0
# 2546947  U2KZI_ELoyvlBq_RVR7t2Q      4       0      0     0
# 2546948  pWEvUo4JWXohCVurC6U_Mw      5       0      0     0
#
#                        date
# 0       2014-10-11 03:34:02
# 1       2015-07-03 20:38:25
# 2       2013-05-28 20:38:06
# 3       2010-01-08 02:29:15
# 4       2011-07-28 18:05:01
# ...                     ...
# 2546944 2015-12-15 02:05:09
# 2546945 2019-03-03 19:40:03
# 2546946 2018-12-02 16:31:03
# 2546947 2021-01-22 20:17:11
# 2546948 2021-01-22 23:05:15
#
# [2546949 rows x 8 columns]

# %%
userbiz_revpair = dfrev.iloc[:,0:3]
userbiz_revpair = userbiz_revpair.rename(columns={'review_id': 'Review', 'business_id': 'Business', 'user_id': 'User'})

# %%
userbiz_revpair[1:2]['Business']
# Out:
# 1    RA4V8pr014UyUbDvI-LW2A
# Name: Business, dtype: object

# %%
test_rev = []
testing = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == 'buF9druCkbuXLX526sGELQ']
testing = pd.DataFrame(testing).to_numpy()
test_rev.append(testing)
print(test_rev)
print(len(test_rev))
test2 = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == 'RA4V8pr014UyUbDvI-LW2A']
test2 = pd.DataFrame(test2).to_numpy()
test_rev.append(test2)
print(test_rev)
print(len(test_rev))
df_test = pd.DataFrame(test_rev, columns = ['Review', 'User', 'Business'])
df_test
# Out:
# [array([['lWC-xP3rd6obsecCYsGZRg', 'ak0TdVmGKo4pwqdJSTLwWw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hpcZLEzqD4_gPi6eSVi_Bg', 'Y-j2svl0M_5-jF1ehYuNPQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['3FvY1Se8y2WXqTbaANOqMw', 'xUCX4GhBpeWxZB0l2lmt_w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['C1uQNP2ehBktS43ZRMEvkg', '2M6KFsWIUXElqcQRz4A0Qg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Cja8_35_kQDnF9g4voikzw', 't5SRIRU6INiAyVkiMJhRPA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['iBd6WvCXER9aU6xfR8YtMA', 'Kgz8xohZN1r2e-qN5GQ2pQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['SDGgNabvLJ_XqXLmSGxZ6w', '1kM4jg4O-tFrmuBBnb8wdA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['0amIc8rKH1E8dMNFMu5MeA', 'djp57omz9cccV1wI0_sqqA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['OylWt3UcDEbOr2XlXRHpZA', 'l0gxisitVlPxXVQiIaEj7A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['a_hHSmxAS3PQdgwOSsW92Q', 'HqOZgH-DKWov7a0UmzM00Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['A-KIqbE4pMSvBEA6nEqB4A', 'avQ84oaYIM0YTh2FkfSFzQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hSdEZpV9suKfWd6LNk_a4w', 'v_PkpS5XhCACvvYe_8V6WQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['tnCbwex2if5kYzn6o4fbvQ', 'jpiv6qQOv6FD8NbLfLFxTA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MCBvWmvMpFqCoeelx8zybQ', '0VwTcWSjKWqMzzG0_w8xIg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['4ruhmYkgDL7BhIq0j2yvdg', '7NuAk35FPwEZ1HwVIV5vsw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['RBfLRH-R9vIF8sW_rkV-uw', 'ktOZ79iHU4DUif_8aAEjZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['LwJ94zq2s7gEmEQZQLr6Tg', 'u1Y6J-Ef4Skn8sJ1TpAoaw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['5MX-VcG-54t5J5ExM2rnTw', 'issfnrsMzmczjahtzNldaw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['_b3eCEj4e0G_1boc_kSh3g', 'P3yRZq_usBrjs0veSgPmgg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JSp-GCVJxAYk3ctJA9iTiA', 'CAa5pUKYDiiXhnO_ie7CHw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['W7T4fqDnjCG-s25S-YaMMw', 'Pf4znQEWoL7DY1mntu2VeQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['anF_7ZGtW16iUEhJovS48g', 'c-Nuhw2acbo7rGuZMCEvEA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['PGpjJwsqUV70xfm1cqucjQ', 'mqAFsswW-6idNOfSCCz3OQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['r4-JPMplwiHBgDz_G3D4Bw', 'oe8ag0iSSo_gxhSlDXt46w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['BPrTL0G76IyzGyzVlTa88g', '8DtqS0yhbIKrJJNDyKo2Ig',
#         'buF9druCkbuXLX526sGELQ'],
#        ['vB8BSmJbTG3nOaRCwXxg7Q', 'oDH5vkIDyX5qRos7Ne5uJw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['dhqD_Ll5-QWgUedOF57thA', 'qzOSHAjp5ZELbss6FFNxnQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['dKAVnXjoXA5fTFHbLDTmoA', '6LI3C0QEwjQ3xGoHjs-Vtg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7Sj-srYIC72BbGJXYQQwEA', '1wjAOyoBauz_al_SLqITrQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['etzb04XKouL0HmMhVvFrkQ', 'ljvgd9ksG-q3ZY9loBwS6w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EDft5yxdRa-GLpRD-RRO8w', 'zLltB1M2bPDIQl4X8gYdsQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['PimghCCm3d1bNIkx4glXow', 'g35OBHqo6AnJNMHSfp6IQw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7MHGQecjrx1bqr5-1dA3gQ', 'kAaoaiYkwzddLvOm4FVj1g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['KcATtLxxawRU2r7Wdm_d7Q', 'jmKkv7qswo7sD2MuyjR9uw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['fNPyGrhvDOJizfpwwWf2Ww', 'D3dBAZAqWR485wXwknbxcA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['jFsNMwVSQlAW1v5p7D4Scw', 'Oc56GrSA7DhuU95WIqiG4g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['92d0ElSVY-PPtcAXw1IMSQ', '4w7TXcPola5W7Mf_8xJi5A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['xDYpVxWHmNOnKV1_wJbBww', 'DIB4IaGdro00-pZI1Hz84w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['WNvBu2ELmkJ47R7klwbbdQ', '8iuZoPo2CCOfkdpzPqlbJA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['D4QNLXP6iu1g4S1_YsQOzg', 'M1Y5rzgNKUA50B5aNSldWQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Pi_iq7yJRYAxKl6lSiHFGQ', 'CGP7MaThT2fpKOyQ7w9irw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['0kSjqKWu0Z-cTDpUOv9N6g', 'p0Jj0BdJLkuGBOJV8M2VNQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['CnM3u3JSVWuqwLcdx0NHzA', 'LGN94e8YgLlZCJ0Tau59YA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JPDRW58uCiEyBIf5yVO6GQ', 'iWuIB0Sa5Dr_rO5U4SjReg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['xSc7H6k134oG75BNWR7A-g', 'EOhQ62p42aDoi9NyG7f2qQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['iTzTC52VTqsqvAemEXH-dw', 'wvnwou32Tww-xf27yvFn2Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JdqHpGANJuzBd_xtmWC44g', 'HS_EAlc2lydxZhJLYyH5ZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['2He199ZsfOwFBekfquhwSg', 'hNnt3wrCYJBlJ9UJGE6i3A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['cZVaS4vXswJ5FvQsOzN4EQ', '5Iz1uBe3hkA4li_p_D3Xew',
#         'buF9druCkbuXLX526sGELQ'],
#        ['1h-za0jpnCKtfB5jDyByHw', 'wVC1lGSMNdGNQa4iFWDMPg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['9HJaqJoqsQN1DZBKq1Ow1Q', 'LGBXtRmyE9qbe80L0L2N0Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['J_IIY0yaqUmTDX_bV9Lhvw', 'myI9b-ueoINl3qabbZA8Uw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['a5IYQgHhat41VRO_e290fQ', 'dyduOsXrTKI1S3bSEGwnIw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['z57BFiy9HH-d59ZyMqqllQ', 'FzRSz98ldRjbbN5XClOdrg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EcWZk3kc13f2u57o_BOrWg', '-1DyzG1BVvIMopoHWVZzGA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EJrl3IK8U9JnqSNzqGoUyA', 'Wm5UpzeAJez0tE64OL3ELA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Jgs2q9-9mYkp_4xw-rPUVA', '9FPOWSmRdqBiBZY7A1OLZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['eVu4uXIsL_Rf0K1mr8dyrw', 'gce1BzbxjF0kRyoYQ3uqwg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['UEdqy8iHyF3EQfq6egcD9g', 'sMRucNvjaoSrvo6Jo5yjhA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['BPGoy8p97C1N5ndD-c-H7Q', 'UA7h609PnnxQ-PWz1tf0og',
#         'buF9druCkbuXLX526sGELQ'],
#        ['GSMskMx8uvEuqvuZqwDCVw', 'L-wXDOAvttJlcyQjOqeR2g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Q1Uj9jK8nq0EydEyQQB2Ww', 'ucnz1xvuPv-MrRHK2bimFQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hBwgdQvIB5DCdktaSb_AhQ', '69V0IfO_6AnoXH4KOw4GVQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['O05JorG_WP6d_F_LqB3bZw', 'rLtmJInc-k3L4iT2BuNOUQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MEDFFQ1xK4EDqtnob3AD_w', 'MDSiZwrp-I1KZdONyMzAWQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7rqFIFXs8FYLmNZJhCrBgg', '3xDZ4iEwtiDISGtzV7uCEg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['I9AzxRxXw8L_wcToNQJbig', 'VMjTMjZH4HViLUOFUU8HfA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['RHauXXCzMkpdB8ikZVrOOQ', 't5SRIRU6INiAyVkiMJhRPA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Cz5ZkcskipLaDGvXt7wx2g', 'P_z7AwhFqpHoFC7GOXfAYg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['nrkm1EureFJRvGbbCIMlNg', 'Fiale_9t9G5BIa3K-aaLkA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['bKN2RW_JP1IzKoxjBzqv0Q', 'ZfP1RXH9EcI3HvDtDkw7-Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['x_mcUApfdkXRTnOMsTOirQ', 'NkUeioX-PrbAtMY-qEhZBw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hZGwXXS3Z7s06vaVYrHIsg', 'cp_mCXj5NIVyQCr50qDKVw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MeEkKDt7nPQPVv9ThxiGVg', 'x0ovHnmbGa3UxnDBvXQyBg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['X0anpZXXpQnlCu8VAeF_Cw', '-j73tcQL1ePTmdOmKdjS2w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['fvsLU3bB3-AITm6VC37TDw', 'gN-xMARRCy4Q5cRwa0EkKg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['I6j3FMIf-6QW1jgBj5U3EQ', '3lUdtJ9jQ40A_OOhciGZrw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['K9aPhunQcIAhXeQeTSUzFg', 'ei8D4-v1d_hecHHwNOzcFw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['ln4BANEh4WUZxyleuRbA7w', 'ZGmjA3NrrmcHVX3SoAWaZw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['CLcyMJICyJ24xr7jxVpEaA', 'KWvOFWrxjcHZlrp3wkXL4w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['UYbu06-N6DqlrGt0pNzwZA', '1wWR8xICF5Gl7FW3ysmYew',
#         'buF9druCkbuXLX526sGELQ'],
#        ['kDnGLe_d0U1mKZripuVSQQ', 'csAuIokHiykFWN-d8IBeeg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Md4Z1cC9xsDuxjkwQht47A', 'Z13KzZdBxt4hBLIQkoah4w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['HCbO3G8vgZT-REj6u4wG7Q', 'k3FF12JF7_453Tjp3crNxg',
#         'buF9druCkbuXLX526sGELQ']], dtype=object)]
# 1
# [array([['lWC-xP3rd6obsecCYsGZRg', 'ak0TdVmGKo4pwqdJSTLwWw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hpcZLEzqD4_gPi6eSVi_Bg', 'Y-j2svl0M_5-jF1ehYuNPQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['3FvY1Se8y2WXqTbaANOqMw', 'xUCX4GhBpeWxZB0l2lmt_w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['C1uQNP2ehBktS43ZRMEvkg', '2M6KFsWIUXElqcQRz4A0Qg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Cja8_35_kQDnF9g4voikzw', 't5SRIRU6INiAyVkiMJhRPA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['iBd6WvCXER9aU6xfR8YtMA', 'Kgz8xohZN1r2e-qN5GQ2pQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['SDGgNabvLJ_XqXLmSGxZ6w', '1kM4jg4O-tFrmuBBnb8wdA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['0amIc8rKH1E8dMNFMu5MeA', 'djp57omz9cccV1wI0_sqqA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['OylWt3UcDEbOr2XlXRHpZA', 'l0gxisitVlPxXVQiIaEj7A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['a_hHSmxAS3PQdgwOSsW92Q', 'HqOZgH-DKWov7a0UmzM00Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['A-KIqbE4pMSvBEA6nEqB4A', 'avQ84oaYIM0YTh2FkfSFzQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hSdEZpV9suKfWd6LNk_a4w', 'v_PkpS5XhCACvvYe_8V6WQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['tnCbwex2if5kYzn6o4fbvQ', 'jpiv6qQOv6FD8NbLfLFxTA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MCBvWmvMpFqCoeelx8zybQ', '0VwTcWSjKWqMzzG0_w8xIg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['4ruhmYkgDL7BhIq0j2yvdg', '7NuAk35FPwEZ1HwVIV5vsw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['RBfLRH-R9vIF8sW_rkV-uw', 'ktOZ79iHU4DUif_8aAEjZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['LwJ94zq2s7gEmEQZQLr6Tg', 'u1Y6J-Ef4Skn8sJ1TpAoaw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['5MX-VcG-54t5J5ExM2rnTw', 'issfnrsMzmczjahtzNldaw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['_b3eCEj4e0G_1boc_kSh3g', 'P3yRZq_usBrjs0veSgPmgg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JSp-GCVJxAYk3ctJA9iTiA', 'CAa5pUKYDiiXhnO_ie7CHw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['W7T4fqDnjCG-s25S-YaMMw', 'Pf4znQEWoL7DY1mntu2VeQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['anF_7ZGtW16iUEhJovS48g', 'c-Nuhw2acbo7rGuZMCEvEA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['PGpjJwsqUV70xfm1cqucjQ', 'mqAFsswW-6idNOfSCCz3OQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['r4-JPMplwiHBgDz_G3D4Bw', 'oe8ag0iSSo_gxhSlDXt46w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['BPrTL0G76IyzGyzVlTa88g', '8DtqS0yhbIKrJJNDyKo2Ig',
#         'buF9druCkbuXLX526sGELQ'],
#        ['vB8BSmJbTG3nOaRCwXxg7Q', 'oDH5vkIDyX5qRos7Ne5uJw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['dhqD_Ll5-QWgUedOF57thA', 'qzOSHAjp5ZELbss6FFNxnQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['dKAVnXjoXA5fTFHbLDTmoA', '6LI3C0QEwjQ3xGoHjs-Vtg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7Sj-srYIC72BbGJXYQQwEA', '1wjAOyoBauz_al_SLqITrQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['etzb04XKouL0HmMhVvFrkQ', 'ljvgd9ksG-q3ZY9loBwS6w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EDft5yxdRa-GLpRD-RRO8w', 'zLltB1M2bPDIQl4X8gYdsQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['PimghCCm3d1bNIkx4glXow', 'g35OBHqo6AnJNMHSfp6IQw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7MHGQecjrx1bqr5-1dA3gQ', 'kAaoaiYkwzddLvOm4FVj1g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['KcATtLxxawRU2r7Wdm_d7Q', 'jmKkv7qswo7sD2MuyjR9uw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['fNPyGrhvDOJizfpwwWf2Ww', 'D3dBAZAqWR485wXwknbxcA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['jFsNMwVSQlAW1v5p7D4Scw', 'Oc56GrSA7DhuU95WIqiG4g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['92d0ElSVY-PPtcAXw1IMSQ', '4w7TXcPola5W7Mf_8xJi5A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['xDYpVxWHmNOnKV1_wJbBww', 'DIB4IaGdro00-pZI1Hz84w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['WNvBu2ELmkJ47R7klwbbdQ', '8iuZoPo2CCOfkdpzPqlbJA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['D4QNLXP6iu1g4S1_YsQOzg', 'M1Y5rzgNKUA50B5aNSldWQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Pi_iq7yJRYAxKl6lSiHFGQ', 'CGP7MaThT2fpKOyQ7w9irw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['0kSjqKWu0Z-cTDpUOv9N6g', 'p0Jj0BdJLkuGBOJV8M2VNQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['CnM3u3JSVWuqwLcdx0NHzA', 'LGN94e8YgLlZCJ0Tau59YA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JPDRW58uCiEyBIf5yVO6GQ', 'iWuIB0Sa5Dr_rO5U4SjReg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['xSc7H6k134oG75BNWR7A-g', 'EOhQ62p42aDoi9NyG7f2qQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['iTzTC52VTqsqvAemEXH-dw', 'wvnwou32Tww-xf27yvFn2Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['JdqHpGANJuzBd_xtmWC44g', 'HS_EAlc2lydxZhJLYyH5ZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['2He199ZsfOwFBekfquhwSg', 'hNnt3wrCYJBlJ9UJGE6i3A',
#         'buF9druCkbuXLX526sGELQ'],
#        ['cZVaS4vXswJ5FvQsOzN4EQ', '5Iz1uBe3hkA4li_p_D3Xew',
#         'buF9druCkbuXLX526sGELQ'],
#        ['1h-za0jpnCKtfB5jDyByHw', 'wVC1lGSMNdGNQa4iFWDMPg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['9HJaqJoqsQN1DZBKq1Ow1Q', 'LGBXtRmyE9qbe80L0L2N0Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['J_IIY0yaqUmTDX_bV9Lhvw', 'myI9b-ueoINl3qabbZA8Uw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['a5IYQgHhat41VRO_e290fQ', 'dyduOsXrTKI1S3bSEGwnIw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['z57BFiy9HH-d59ZyMqqllQ', 'FzRSz98ldRjbbN5XClOdrg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EcWZk3kc13f2u57o_BOrWg', '-1DyzG1BVvIMopoHWVZzGA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['EJrl3IK8U9JnqSNzqGoUyA', 'Wm5UpzeAJez0tE64OL3ELA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Jgs2q9-9mYkp_4xw-rPUVA', '9FPOWSmRdqBiBZY7A1OLZQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['eVu4uXIsL_Rf0K1mr8dyrw', 'gce1BzbxjF0kRyoYQ3uqwg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['UEdqy8iHyF3EQfq6egcD9g', 'sMRucNvjaoSrvo6Jo5yjhA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['BPGoy8p97C1N5ndD-c-H7Q', 'UA7h609PnnxQ-PWz1tf0og',
#         'buF9druCkbuXLX526sGELQ'],
#        ['GSMskMx8uvEuqvuZqwDCVw', 'L-wXDOAvttJlcyQjOqeR2g',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Q1Uj9jK8nq0EydEyQQB2Ww', 'ucnz1xvuPv-MrRHK2bimFQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hBwgdQvIB5DCdktaSb_AhQ', '69V0IfO_6AnoXH4KOw4GVQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['O05JorG_WP6d_F_LqB3bZw', 'rLtmJInc-k3L4iT2BuNOUQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MEDFFQ1xK4EDqtnob3AD_w', 'MDSiZwrp-I1KZdONyMzAWQ',
#         'buF9druCkbuXLX526sGELQ'],
#        ['7rqFIFXs8FYLmNZJhCrBgg', '3xDZ4iEwtiDISGtzV7uCEg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['I9AzxRxXw8L_wcToNQJbig', 'VMjTMjZH4HViLUOFUU8HfA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['RHauXXCzMkpdB8ikZVrOOQ', 't5SRIRU6INiAyVkiMJhRPA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Cz5ZkcskipLaDGvXt7wx2g', 'P_z7AwhFqpHoFC7GOXfAYg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['nrkm1EureFJRvGbbCIMlNg', 'Fiale_9t9G5BIa3K-aaLkA',
#         'buF9druCkbuXLX526sGELQ'],
#        ['bKN2RW_JP1IzKoxjBzqv0Q', 'ZfP1RXH9EcI3HvDtDkw7-Q',
#         'buF9druCkbuXLX526sGELQ'],
#        ['x_mcUApfdkXRTnOMsTOirQ', 'NkUeioX-PrbAtMY-qEhZBw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['hZGwXXS3Z7s06vaVYrHIsg', 'cp_mCXj5NIVyQCr50qDKVw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['MeEkKDt7nPQPVv9ThxiGVg', 'x0ovHnmbGa3UxnDBvXQyBg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['X0anpZXXpQnlCu8VAeF_Cw', '-j73tcQL1ePTmdOmKdjS2w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['fvsLU3bB3-AITm6VC37TDw', 'gN-xMARRCy4Q5cRwa0EkKg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['I6j3FMIf-6QW1jgBj5U3EQ', '3lUdtJ9jQ40A_OOhciGZrw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['K9aPhunQcIAhXeQeTSUzFg', 'ei8D4-v1d_hecHHwNOzcFw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['ln4BANEh4WUZxyleuRbA7w', 'ZGmjA3NrrmcHVX3SoAWaZw',
#         'buF9druCkbuXLX526sGELQ'],
#        ['CLcyMJICyJ24xr7jxVpEaA', 'KWvOFWrxjcHZlrp3wkXL4w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['UYbu06-N6DqlrGt0pNzwZA', '1wWR8xICF5Gl7FW3ysmYew',
#         'buF9druCkbuXLX526sGELQ'],
#        ['kDnGLe_d0U1mKZripuVSQQ', 'csAuIokHiykFWN-d8IBeeg',
#         'buF9druCkbuXLX526sGELQ'],
#        ['Md4Z1cC9xsDuxjkwQht47A', 'Z13KzZdBxt4hBLIQkoah4w',
#         'buF9druCkbuXLX526sGELQ'],
#        ['HCbO3G8vgZT-REj6u4wG7Q', 'k3FF12JF7_453Tjp3crNxg',
#         'buF9druCkbuXLX526sGELQ']], dtype=object), array([['8bFej1QE5LXp4O05qjGqXA', 'YoVfDbnISlW0f7abNQACIg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['oTrswLb-VbgO7pasrLvPpw', 'Bla4CIPFN8UTfdrVaZBYig',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['mk5n7YkLiwyK-3dzAkPOjg', 'gl9qV-mVj2jAGzEDVJ1LnA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['cGwzhseezuCBP2DO5-DORA', '8hFaIPgGB7UB5XeswphdQA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['qOg_gGJlQ_7K6ciKeHrk2g', 'r0qmMCot9riZKb_Web6l-g',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['kQapJwwkTwsdQcnBXSRzvA', 'boKeKIaa3SZ7HMKxuqNa9Q',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['8WOWMJ-LcwO5SsnlGCQ4pg', 'nl8gWLDo6U6MjqzbBmE_9A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['szeBuFhFOsluOrqnz3igHw', 'X3xV2Rdbi_ETgLtuJNwfqQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['I-bb30tcSfFNhCxvz2Sh8A', 'u4t0wqjJ-xkZ0iJu48jkXw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['-kJ_6Ww6yIZp7yqCcGqfJg', 'DPDKjg5iKBlK4DDwnamq3A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['AOdIWrtg6AdwfM-CMs3-xw', 't5cTUYXB6mA8JrRF746wuw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['jRBQh7IxdLBP6e3ObHnHpg', 'YGEgN9MYVqVxHtnPcBdnYQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['5wIrh0JHiHqeBwgm7K1FCQ', 'iCppbv3C7XvCyzIZnNQ7fg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['KEqK0ecw5ifpBLFwZSIm0w', '6Ib9WmBBLObx341Ue5VhVQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['OoghdNeLSFTz-BcUiGwqUA', '_R_nNi6Gc7oNaNK44_M68A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['oGqW0iZs7nHfNmbxJ0g16w', 'DTerWbIMkBafUJAKI1gaPw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['8N9_tCjmoJkdTRD-R3xEpw', 'weEns7WVtPAgrHuxYpvwOg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['qWs07-WjARcLmgN_VzLEeA', 'JuHctJ4Q-ffRjrQiVeTQFw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['fSlLBuEGarh1ZbqH2M_OKg', 'yyb10JbFROwOYmAr6OmXbQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['xPM-R96jdSx6yNOK7y_ttg', 'uSTze3kFhbgu4GCf1IlbUQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['7XWbVm1RHBAio_9FmNRc_w', 'HnA4k2WObb00F4tW1MOhdg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['EhrPKXEJ4x1TgRLCIq_aIg', 'njEa-gaTTxMueydgu0gUkg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['zaSNWgS0kpJBIgT13oIxmg', 'XEPbCohFwrT5CxJRNdOtYg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['t9mxwIdsUnSIP5DaNkug2Q', 'YoVfDbnISlW0f7abNQACIg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Bf5mmHSmTNzfjgo2gUDrcQ', 'njEa-gaTTxMueydgu0gUkg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Oya_MWAr7fq-PzcvfQtHsg', 'zP0OY4FJjFOrggA-dgXz-A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Uyc24Q_LJbCW5CKevdNdAA', 'LdIe4P-q-ASbyX0bW_Bu0g',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['W53oIqVOEDErQAYbNnqtZQ', 'OoSfCSku0zgAeFD6SKE95Q',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['8tMdpvrlsWH3w71NdVwoug', 'OHMZcYZ-SLi6W3r_9i-Wpw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['zlHN8sOmT6k_ALuuQxvJOg', 'YkBLJs6ZJoHoDxsxjQjXsA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['S92JnD7IXxyavO5G0_mOEw', 'VPXlPM5abV5tYF57qe0MPw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Rs3EB7Ut0DyuPdZFiHIDaA', 'mHDisNpWKB-3M_83j7bZ5Q',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['sKYmEQ3bKwFK6nbYEggJNQ', 'NJ6kZJ2hBA7cSfwWiy-ruQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['6IGlbUj4nNciZE6IYvEG0g', 'JdKuRm1p48t3_0W319zltg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['LfRVWovdYAr9FLLZAcbHnQ', 'x98uvg9_0mE2c69PIZvf3A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['3d1guUgdXA3-cBEL8n9AzQ', 'XKxkdgwClIv6RsxCtjPmCA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['ikxN2exBb3WjW6AwUZr6iw', 'pXGk3GizqmX1OGd3d8YA6A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['0GDvAflqjGccYGzdBA9XOA', 'MX8HZOxRRnQC0xrQ4fqv7A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['3K1Jn4256m7oB4_BzTNR1A', 'belkExx9ktP516XiqPxCDg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['eJjfGbW1_LJXQjV43m_sdQ', 'BxN1P9y4x359Hkm83DyZZA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['EvV3paAGSAsUcEUlV_lnhQ', 'qsWCoNJiNNeusP0KI7oN8w',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['6YREW5PelAwxGbl8KUeliQ', 'njEa-gaTTxMueydgu0gUkg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['WV10Tw-7V3g_zHUdhLxp9Q', 'VPXlPM5abV5tYF57qe0MPw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['TXeEzcDyw3eJzbcWCs-XTw', 'q31f3uFJsFTNFFolAQkWCQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Myf1sIB85XyLbsC07DI6RQ', 'k71eOhdS8h_-G7ItX8serQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['frjVnWxasp0JzXqIIFV-tg', 'wXhM5a0NTk6Z82bQrg40cw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['At6vKfkaS8cvzOtuCe-L9w', 'AjkbbtosgHockU0Li21vwQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['a6_BbsRilnnkGNQHAKPEDg', 'gaE1tf-vokGPpcu9_oniHQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['h57CKidbFgmu6DxLNiSJSg', 'D51dPy_419brBH7S3hxfkA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['dKxUgsLKPQCoSMdDnvl4SA', '3HyU8XTtBD7NfYDYKu7fQw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['7o-6qsKNqZuq-nRv59YhQw', 'dkVYZDQcjBLxU5bL-2yshA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['0XTXZfICWgTbKBoOKdVi1Q', '3san8VObp6FYMaL_I8KJpQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['yVudHcHK3bFzaK5lJEqSwA', 'JdKuRm1p48t3_0W319zltg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['HlZVdG9yITYffh_vCeMzaQ', '4GSy-M2KDu4nTygq_dYq2Q',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['v09AvHEIQHh362QIbpjN4w', 'gf9jJizhRUx7mXyq8vLicg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['IG2-IhnJgXsG5dCQig6NZQ', 'LcsA_A2XgQikhcbhAKpeiQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['mmhWDVDTf-kVU1YOhIPLsw', 'jhgJVq704e7jUqzty2VgtA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['hRUyzOmWma9bmIAY0O-S9g', '-05faERStJZLFBVgM60lzw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['3dYjwmfETh-ic2nzBXJrxw', 'bqPu5ZVf7ykxdOWWG2zGSg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['UUm3KdQqxyf1t9nUHVGo0A', 'kSg8EX6XbSonzHNBXq4Agg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['KWYbbmR0dWH1fRD5Eu_w0w', 'OznrIguWJMFfpQNlaNwYjg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['WYtaINYzICSUyzKN89ZFdw', 'Ao1EUH0FlzW46bESSymXUA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['8gzHr7CtcoKEbZvj8PdsaQ', '34ajWp32NWdfw20xzZOiFw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['Nk1CkObbvlrPAwp9Kh1eZw', 'yu7B2b_8pI5jV46uU08NMA',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['fzlAsD7Jnc2UHJMqHUkVgg', 'fgoDs7Q_KVDWBW69SajZpg',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['OuuQMhuvltMQWgm2grUM_w', '_95Tzx_4lxP6K1IItrfQyw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['agg6nmPnrAT3g6HFCq2kiw', 'LizhIXojp7JfFfyz0nn97A',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['nJ5AzsixH9c340J0vpqnfQ', 'iqCeouOPrpqVcy_mirS_Iw',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['74p8TQH9yIdFKHF9ydL-mw', 'Vbl6Q9-TLHuXS4KWtK1ekQ',
#         'RA4V8pr014UyUbDvI-LW2A'],
#        ['9RnvQZ4TqUKQ4lrTsPC-2w', 'QxkY9qWDNQbsxSpZbvyPVg',
#         'RA4V8pr014UyUbDvI-LW2A']], dtype=object)]
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2377
# -> 2378         super().__init__(values, ndim=ndim, placement=placement)
#    2379
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     129         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 130             raise ValueError(
#     131                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-f4ab73dad19d> in <module>
#      10 print(test_rev)
#      11 print(len(test_rev))
# ---> 12 df_test = pd.DataFrame(test_rev, columns = ['Review', 'User', 'Business'])
#      13 df_test
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     521                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     522                 else:
# --> 523                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     524             else:
#     525                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670         blocks = [getattr(b, "values", b) for b in blocks]
#    1671         tot_items = sum(b.shape[0] for b in blocks)
# -> 1672         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1673
#    1674
#
# ValueError: Shape of passed values is (2, 1), indices imply (2, 3)

# %%
bis = df.loc[df['state'] == 'WA']
bis_ids = bis[0:]['Business']
bis_ids = pd.DataFrame(bis_ids).to_numpy()
## filter for city
city_reviews = []
for i in bis_ids:
    business = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == i[0]]
    if (business.empty != True):
        business = pd.DataFrame(business).to_numpy()
    for j in range(0,len(business)):
        city_reviews.append(business[j])
    
dfcity = pd.DataFrame(city_reviews, columns = ['Review', 'User', 'Business'])
print(dfcity)
# Out:
#                        Review                    User                Business
# 0      PYrtPsd07oBSDp5HF5zQPg  XILSEok-O_4pBRWqfEv6uA  Yyym58vWvlRPuMCOICWRBw
# 1      qC9fMfucTub9pDaPguHJqw  -WjK92cNNSoJwm89uvb75A  Yyym58vWvlRPuMCOICWRBw
# 2      eLbDL0C4mg_2ypW69HoFIQ  Mto4EEpGm_Q4dDUUYYweRQ  Yyym58vWvlRPuMCOICWRBw
# 3      _7b-5RFgd8vb-ggFFG-kWQ  pyArLpxxzDYZQj7-x9nFiA  Yyym58vWvlRPuMCOICWRBw
# 4      yR3FL8UMyV_Cn2Of2IulGQ  ptb2nEgBng_wjZFD8Y0GfA  Yyym58vWvlRPuMCOICWRBw
# ...                       ...                     ...                     ...
# 36770  kMhgaKNqeSQHCJHTEy-iFQ  AgaHp8v8_ovLJY7QkP3SGw  Po3MPZ9ky6EzABt6G9jqWw
# 36771  kQ0tkdpulF3YR13EHHi9Mw  8PHaGSKDNOoqmvS1zEggrQ  Po3MPZ9ky6EzABt6G9jqWw
# 36772  XcdbGjurB8-o4mnifLJ9eQ  xxITyykPbM3lDQNarjEndA  Po3MPZ9ky6EzABt6G9jqWw
# 36773  f1pXJMcDN_1L-L2838UzHQ  6601h2G7YEgmoJA2OHr3EA  Po3MPZ9ky6EzABt6G9jqWw
# 36774  U1aW4Cg2MJtnHtuZeOBqLA  QXdSMCcwx3E8H4zQ_v7Vgg  Po3MPZ9ky6EzABt6G9jqWw
#
# [36775 rows x 3 columns]

# %%
# Out:
# array(['1CHPSnEh4axD10HCqe8k-A'], dtype=object)

# %%
userbiz_revpair[0:]
# Out:
#                          Review                    User  \
# 0        lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw
# 1        8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg
# 2        NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw
# 3        T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA
# 4        sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A
# ...                         ...                     ...
# 2546944  CNfG18etDobCn-LlyH3TtQ  s6ZuqZLSlKvVZElSEd03Gw
# 2546945  uxIlS76PxfWxBZt4LgvZFg  caiSZUruSw1fkVOHtlS4kw
# 2546946  OAG58lQj7cWVT57M81oCDg  Jax59T2jZ5qrMwB4MmxChw
# 2546947  mdk2z1NasChYZf3ztlnwFA  _vpRHhJxPnse-xEt7tKb3A
# 2546948  mFhTJpR_vQKdvBS9NgXj0Q  UR1Vd8oFXfxunpBCuuPJ5Q
#
#                        Business
# 0        buF9druCkbuXLX526sGELQ
# 1        RA4V8pr014UyUbDvI-LW2A
# 2        _sS2LBIGNT5NQb6PD1Vtjw
# 3        0AzLzHfOJgL7ROwhdww2ew
# 4        8zehGz9jnxPqXtOc7KaJxA
# ...                         ...
# 2546944  sB9dNoHtrJ6YDU1ynz4lcg
# 2546945  U65ez9BbaXyqKrqI1Atviw
# 2546946  0fWr9Ty_EGvimZ4h6Rw2yg
# 2546947  U2KZI_ELoyvlBq_RVR7t2Q
# 2546948  pWEvUo4JWXohCVurC6U_Mw
#
# [2546949 rows x 3 columns]

# %% [markdown]
# ## Information Cascade

# %%
userbiz_revpair = dfrev.iloc[:,0:4]
userbiz_revpair = userbiz_revpair.rename(columns={'review_id': 'Review', 'business_id': 'Business', 'user_id': 'User'})
# pass in userbiz_revpair as an array
def info_casc(bizid):
    biz_revs = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == bizid]
    x = np.arange(1, len(biz_revs['stars'])+1, 1)
    plt.plot(x, biz_revs['stars'])
    plt.xlabel('Review Number')
    plt.ylabel('Star Rating')
    plt.title('Reviews over time for business', bizid)

# %%
biz_revs = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == 'R8fLQ6TLz06MQR69KQJ83g']
biz_revs['stars']
len(biz_revs['stars'])
x = np.arange(1, len(biz_revs['stars'])+1, 1)
x
plt.scatter(x, biz_revs['stars'])

# %% [markdown]
# ### top two in colorado

# %%
info_casc()

# %% [markdown]
# ### bottom two in colorado

# %%
info_casc()

# %%
wash_auth
# Out:
#                    Business  Auth Score
# 100  R8fLQ6TLz06MQR69KQJ83g        3030
# 236  JkhXi-3RJtmUTlkjrSdWSw        2840
# 160  rgGJMwcrNTuCcY493q_YuA        2373
# 49   TDQ0lSTHW3RyfVWQuwbBGg        2322
# 157  PgAihGrv8kHaV_6zIAwvEQ        2145
# ..                      ...         ...
# 42   zqMeyheGDu5f5xACncsosw           5
# 781  O0UPp54_jWnlYujfL5eudw           5
# 784  5l_9qACn1gU2omzZWbc70w           5
# 787  dHM0Y69CvH9xEQaAJDv1nQ           4
# 691  8u_Btq9k829del1_UPwW9A           3
#
# [974 rows x 2 columns]

# %% [markdown]
# ### top two in wash

# %%
info_casc('R8fLQ6TLz06MQR69KQJ83g')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-fc93d1123924> in <module>
# ----> 1 info_casc('R8fLQ6TLz06MQR69KQJ83g')
#
# <ipython-input-137-eb3fb1c6af9c> in info_casc(bizid)
#       8     plt.xlabel('Review Number')
#       9     plt.ylabel('Star Rating')
# ---> 10     plt.title('Reviews over time for business', bizid)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3106 @_copy_docstring_and_deprecators(Axes.set_title)
#    3107 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3108     return gca().set_title(
#    3109         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3110
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     190         title.update(default)
#     191         if fontdict is not None:
# --> 192             title.update(fontdict)
#     193         title.update(kwargs)
#     194         return title
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py in update(self, kwargs)
#     170         sentinel = object()  # bbox can be None, so use another sentinel.
#     171         # Update fontproperties first, as it has lowest priority.
# --> 172         fontproperties = kwargs.pop("fontproperties", sentinel)
#     173         if fontproperties is not sentinel:
#     174             self.set_fontproperties(fontproperties)
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
info_casc('JkhXi-3RJtmUTlkjrSdWSw')

# %% [markdown]
# ### bottom two in wash

# %%
info_casc('dHM0Y69CvH9xEQaAJDv1nQ')

# %%
info_casc('8u_Btq9k829del1_UPwW9A')

# %% [markdown]
# # Filter by City Function

# %%
userbiz_revpair = dfrev.iloc[:,0:3]
userbiz_revpair = userbiz_revpair.rename(columns={'review_id': 'Review', 'business_id': 'Business', 'user_id': 'User'})
# pass in userbiz_revpair as an array
def filter_city(state):
    bis = df.loc[df['state'] == state]
    bis_ids = bis[0:]['Business']
    bis_ids = pd.DataFrame(bis_ids).to_numpy()
    ## filter for city
    city_reviews = []
    for i in bis_ids:
        business = userbiz_revpair.loc[userbiz_revpair[0:]['Business'] == i[0]]
        if (business.empty != True):
            business = pd.DataFrame(business).to_numpy()
        for j in range(0,len(business)):
            city_reviews.append(business[j])

    dfcity = pd.DataFrame(city_reviews, columns = ['Review', 'User', 'Business'])
     
    bis_ids_rev = dfcity.Business.unique()
    biz_stats = []
    by_biz = dfcity.groupby('Business')

    for i in range(0,len(bis_ids_rev)):
        biz = bis_ids_rev[i]
        total_rev = len(by_biz.get_group(biz))
        biz_stats.append([biz,total_rev])
    df_biztotalrev = pd.DataFrame(biz_stats, columns = ['Business', 'Number of Reviews Received'])

    city_ind_id = dfcity.User.unique()
    ind_stats = []
    by_ind = dfcity.groupby('User')

    for i in range(0,len(city_ind_id)):
        ind = city_ind_id[i]
        total_rev = len(by_ind.get_group(ind)['Review'])
        ind_stats.append([ind,total_rev])
    df_indtotalrev = pd.DataFrame(ind_stats, columns = ['User', 'Number of Reviews Given'])
    
    city_hubs = df_indtotalrev.rename(columns={'Number of Reviews Given': 'Hub Score'})
    city_auth = df_biztotalrev.rename(columns={'Number of Reviews Received': 'Auth Score'})
    
    return  city_hubs, city_auth, dfcity

# %%
## Hub and Authorities

def h_and_a(k, hubs, auth, dfcity):
    ind_ids = hubs.User.unique()
    biz_ids = auth.Business.unique()
    
    by_ind = dfcity.groupby('User')
    by_biz = dfcity.groupby('Business')
    
    for a in range(0,k):
        # one round update authority scores
        for j in range(0,len(biz_ids)):
            biz = biz_ids[j] # finds business j
            biz_users = np.asarray(by_biz.get_group(biz)['User']) # forms array with user id of all users who have reviewed business j
            authscore = 0 # restarts authority score
            for i in range(0,len(biz_users)):
                ind = biz_users[i] # for every user i that has reviewed business j
                authscore = authscore + int(hubs.loc[hubs['User']== ind]['Hub Score'])
            auth.at[j,'Auth Score'] = authscore
            
        # one round update hub scores
        for i in range(0,len(ind_ids)):
            ind = ind_ids[i] # finds ind i 
            ind_busi = np.asarray(by_ind.get_group(ind)['Business']) # forms array with business id of all businesses reviewed by ind
            hubscore = 0 # restarts hub score
            for j in range(0,len(ind_busi)):
                biz = ind_busi[j] 
                hubscore = hubscore + int(auth.loc[auth['Business']== biz]['Auth Score'])
            hubs.at[i,'Hub Score'] = hubscore
        
        return hubs, auth

# %%
## Star Ratings and Scores
def compare(hubs, auth):
    ind_ids = hubs.User.unique()
    biz_ids = auth.Business.unique()
    dfbizrate = df.iloc[:,np.r_[0:2, 8]]
    dfuserrate = dfuser.iloc[:,np.r_[0:1, 4, 10]] 
    
    # filtering business data
    city_bizrate = []
    for i in biz_ids:
        biz = dfbizrate.loc[dfbizrate[0:]['Business'] == i]
        biz = pd.DataFrame(biz).to_numpy()
        city_bizrate.append(biz)
        
    
    # filtering user data
    city_userrate = []
    for i in ind_ids:
        ind = dfuserrate.loc[dfuserrate[0:]['User'] == i]
        if (ind.empty != True):
            ind = pd.DataFrame(ind).to_numpy()
            #print(ind)
            city_userrate.append(ind)
    
    # arrays to datframes
    city_userrate = pd.DataFrame(city_userrate, columns = ['User', 'useful', 'average_stars'])
    city_bizrate = pd.DataFrame(city_bizrate, columns = ['Business', 'Name', 'stars'])
    
    city_userrate = city_userrate[city_userrate.User != '#NAME?']
    city_bizrate = city_bizrate[city_bizrate.Business != '#NAME?']
    
    # Adding Authority Scores
    city_auth_scores = []

    for i in range (0, len(biz_ids)):
        if(auth['Business'][i] == biz_ids[i]):
            city_auth_scores.append(auth['Auth Score'][i])

    city_bizrate.insert(3, 'Auth Score', city_auth_scores)    
    
    # Adding Hub Scores
    city_hub_scores = []
    for i in range (0, len(ind_ids)):
        if(hubs['User'][i] == ind_ids[i]):
            city_hub_scores.append(hubs['Hub Score'][i])

    city_userrate.insert(3, 'Hub Score', city_hub_scores) 
    
    # Plot Hub
    plt.scatter(city_userrate['useful'], city_userrate['Hub Score'])
    plt.xlabel('Useful Rating')
    plt.ylabel('Hub Score')
    
    plt.scatter(city_userrate['average_stars'], city_userrate['Hub Score'])
    plt.xlabel('Average Star Rating Given')
    plt.ylabel('Hub Score')
    
    # Plot Authority
    
    plt.scatter(city_bizrate['stars'], city_bizrate['Auth Score'])
    plt.xlabel('Average Star Rating')
    plt.ylabel('Authority Score')

# %%
## Star Ratings and Scores
def filter_ratings(hubs, auth):
    ind_ids = hubs.User.unique()
    biz_ids = auth.Business.unique()
    dfbizrate = df.iloc[:,np.r_[0:2, 8]]
    dfuserrate = dfuser.iloc[:,np.r_[0:1, 4, 10]] 
    
    
    # filtering business data
    city_bizrate = []
    for i in biz_ids:
        biz = dfbizrate.loc[dfbizrate[0:]['Business'] == i]
        biz = pd.DataFrame(biz).to_numpy()
        for j in range(0,len(biz)):
            city_bizrate.append(biz[j])
        
    
    # filtering user data
    city_userrate = []
    for i in ind_ids:
        ind = dfuserrate.loc[dfuserrate[0:]['User'] == i]
        if (ind.empty != True):
            ind = pd.DataFrame(ind).to_numpy()
            for j in range(0,len(ind)):
                city_userrate.append(ind[j])
    
    # arrays to datframes
    city_userrate = pd.DataFrame(city_userrate, columns = ['User', 'useful', 'average_stars'])
    city_bizrate = pd.DataFrame(city_bizrate, columns = ['Business', 'Name', 'stars'])
    
    city_userrate = city_userrate[city_userrate.User != '#NAME?']
    city_bizrate = city_bizrate[city_bizrate.Business != '#NAME?']
    
    return city_userrate, city_bizrate

# %%
dfbizrate = df.iloc[:,np.r_[0:2, 8]]
dfbizrate
# Out:
#                       Business                     name  stars
# 0       6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom    4.0
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX    4.0
# 2       bvN78flM8NLprQ1a1y5dRg           The Reclaimory    4.5
# 3       oaepsyvc0J17qwi8cfrOWg              Great Clips    3.0
# 4       PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus    4.0
# ...                        ...                      ...    ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q       Eleven Oaks Realty    4.0
# 160581  bQX-kwVTyZgcdZGEPzce6Q             Webb's Honey    4.5
# 160582  wvFZ06nmPmQ2-IVoPqVYLA    Painting with a Twist    5.0
# 160583  GB75wPibj3IjNauaoCxyGA              Havana Cafe    4.0
# 160584  ngmLL5Y5OT-bYHKU0kKrYA              Zora Grille    4.5
#
# [160585 rows x 3 columns]

# %%
dfuserrate = dfuser.iloc[:,np.r_[0:1, 4, 10]]
dfuserrate
# Out:
#                            User  useful  average_stars
# 0        q_QQ5kBBwlCcbL1s4NVK3g   15038           3.85
# 1        dIIKEfOgo0KqUfGQvGikPg   21272           4.09
# 2        D6ErcUnFALnCQN4b1W_TlA     188           3.76
# 3        JnPIjvC0cmooNDfsa9BmXg    7234           3.77
# 4        37Hc8hr3cw0iHLoPzLK6Ow    1577           3.72
# ...                         ...     ...            ...
# 2189452  OrXXOTSQG2hLEoZ4sw03Gg       0           1.00
# 2189453  pYZ4Dyx5I92u5gDfGiVTpQ       0           4.33
# 2189454  DhrXTJRTLhnvI9UI1q63mg       3           4.20
# 2189455  ka06dBaC9tvKhc7DJ9_7wQ       4           3.89
# 2189456  QfkFTrJ_MdM3Onk6przUJw       0           5.00
#
# [2189457 rows x 3 columns]

# %%
def compare_ratings(hubs, auth):
    ind_ids = hubs.User.unique()
    biz_ids = auth.Business.unique()
    # Adding Authority Scores
    city_auth_scores = []

    for i in range (0, len(biz_ids)):
        if(auth['Business'][i] == biz_ids[i]):
            city_auth_scores.append(auth['Auth Score'][i])

    #city_bizrate.insert(3, 'Auth Score', city_auth_scores)    
    
    # Adding Hub Scores
    city_hub_scores = []
    for i in range (0, len(ind_ids)):
        if(hubs['User'][i] == ind_ids[i]):
            city_hub_scores.append(hubs['Hub Score'][i])

    #city_userrate.insert(3, 'Hub Score', city_hub_scores) 
    
    # Plot Hub
    plot1 = plt.figure(1)
    plt.scatter(city_userrate['useful'], city_userrate['Hub Score'])
    plt.xlabel('Useful Rating')
    plt.ylabel('Hub Score')
    plt.title('Useful Rating Received vs Calculated Hub Score')
    
    plot2 = plt.figure(2)
    plt.scatter(city_userrate['average_stars'], city_userrate['Hub Score'])
    plt.xlabel('Average Star Rating Given')
    plt.ylabel('Hub Score')
    plt.title('Average Star Rating Given vs Calculated Hub Score')
    
    # Plot Authority
    plot3 = plt.figure(3)
    plt.scatter(city_bizrate['stars'], city_bizrate['Auth Score'])
    plt.xlabel('Average Star Rating')
    plt.ylabel('Authority Score')
    plt.title('Average Star Rating vs Calculated Authority Score')

# %%
states = ['BC', 'CO', 'FL', 'GA', 'MA', 'OH','OR', 'TX', 'WA']

# %% [markdown]
# # WA

# %%
hubs, auth, dfcity = filter_city('WA')

# %%
k = 2
hubs, auth = h_and_a(k, hubs, auth, dfcity)

# %%
dfcity
# Out:
#                        Review                    User                Business
# 0      PYrtPsd07oBSDp5HF5zQPg  XILSEok-O_4pBRWqfEv6uA  Yyym58vWvlRPuMCOICWRBw
# 1      qC9fMfucTub9pDaPguHJqw  -WjK92cNNSoJwm89uvb75A  Yyym58vWvlRPuMCOICWRBw
# 2      eLbDL0C4mg_2ypW69HoFIQ  Mto4EEpGm_Q4dDUUYYweRQ  Yyym58vWvlRPuMCOICWRBw
# 3      _7b-5RFgd8vb-ggFFG-kWQ  pyArLpxxzDYZQj7-x9nFiA  Yyym58vWvlRPuMCOICWRBw
# 4      yR3FL8UMyV_Cn2Of2IulGQ  ptb2nEgBng_wjZFD8Y0GfA  Yyym58vWvlRPuMCOICWRBw
# ...                       ...                     ...                     ...
# 36770  kMhgaKNqeSQHCJHTEy-iFQ  AgaHp8v8_ovLJY7QkP3SGw  Po3MPZ9ky6EzABt6G9jqWw
# 36771  kQ0tkdpulF3YR13EHHi9Mw  8PHaGSKDNOoqmvS1zEggrQ  Po3MPZ9ky6EzABt6G9jqWw
# 36772  XcdbGjurB8-o4mnifLJ9eQ  xxITyykPbM3lDQNarjEndA  Po3MPZ9ky6EzABt6G9jqWw
# 36773  f1pXJMcDN_1L-L2838UzHQ  6601h2G7YEgmoJA2OHr3EA  Po3MPZ9ky6EzABt6G9jqWw
# 36774  U1aW4Cg2MJtnHtuZeOBqLA  QXdSMCcwx3E8H4zQ_v7Vgg  Po3MPZ9ky6EzABt6G9jqWw
#
# [36775 rows x 3 columns]

# %%
hubs.to_csv('washington_hubs.csv')

# %%
auth.to_csv('washington_auth.csv')

# %%
dfcity.to_csv('washington_dfcity.csv')

# %%
city_userrate, city_bizrate = filter_ratings(hubs, auth)

ur = len(city_userrate)
br = len(city_bizrate)

with open('washington_userrate.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    for i in range(0,ur):
        mywriter.writerows(city_userrate[i:i+1])
        
with open('washington_bizrate.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    for i in range(0,br):
        mywriter.writerows(city_bizrate[i:i+1])

# %%
city_userrate.to_csv('washington_city_userrate.csv')

# %%
city_bizrate.to_csv('washington_city_bizrate.csv')

# %%
compare_ratings(hubs,auth)

# %%
compare(hubs,auth)

# %%
wash_hubs = hubs.sort_values(by='Hub Score', ascending=False)
wash_hubs
# Out:
#                          User  Hub Score
# 490    f3xJJpUIFWmdZhhc912Leg      51939
# 1244   m0hI5Q0XvtCN6SGmkX-brw      45422
# 787    jB4DwtUC8l0E8iFzAnPozQ      44850
# 117    AbMjnKOwg736fcIu8apuyQ      44585
# 521    wfvtOrGyJbYS61qjaHcJng      41923
# ...                       ...        ...
# 19152  7GhZ8lMAdUSWeW6srMDIJw          4
# 19151  F5KTZyjy4lpNVl0MlIciLw          4
# 17592  s8eytQsl1wqa5qpMqhlxRw          3
# 17591  AZ3FHB_vJPXrqOqo4QHPJQ          3
# 17590  PZ3HI7xZ2gPgpdRzfcOewg          3
#
# [21920 rows x 2 columns]

# %%
wash_auth = auth.sort_values(by='Auth Score', ascending=False)
wash_auth
# Out:
#                    Business  Auth Score
# 100  R8fLQ6TLz06MQR69KQJ83g        3030
# 236  JkhXi-3RJtmUTlkjrSdWSw        2840
# 160  rgGJMwcrNTuCcY493q_YuA        2373
# 49   TDQ0lSTHW3RyfVWQuwbBGg        2322
# 157  PgAihGrv8kHaV_6zIAwvEQ        2145
# ..                      ...         ...
# 42   zqMeyheGDu5f5xACncsosw           5
# 781  O0UPp54_jWnlYujfL5eudw           5
# 784  5l_9qACn1gU2omzZWbc70w           5
# 787  dHM0Y69CvH9xEQaAJDv1nQ           4
# 691  8u_Btq9k829del1_UPwW9A           3
#
# [974 rows x 2 columns]

# %% [markdown]
# ## OH

# %%
hubs, auth, dfcity = filter_city('OH')
hubs, auth = h_and_a(k, hubs, auth, dfcity)

# %%
import csv

h = len(hubs)
a = len(auth)
c = len(dfcity)

with open('ohio_hubs.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    for i in range(0,h):
        mywriter.writerows(hubs[i])
        
with open('ohio_auth.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    for i in range(0,a):
        mywriter.writerows(auth[i])

with open('ohio_dfcity.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    for i in range(0,c):
        mywriter.writerows(dfcity[i])

# %%
compare(hubs,auth)

# %% [markdown]
# ## FL

# %%
hubs, auth, dfcity = filter_city('FL')
hubs, auth = h_and_a(k, hubs, auth, dfcity)
compare(hubs,auth)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f8039f238d08> in <module>
# ----> 1 hubs, auth, dfcity = filter_city('FL')
#       2 hubs, auth = h_and_a(k, hubs, auth, dfcity)
#       3 compare(hubs,auth)
#
# <ipython-input-12-7a1cdc83eab2> in filter_city(state)
#       9     for i in bis_ids:
#      10         business = userbiz_revpair.loc[userbiz_revpair[0:]['business_id'] == i[0]]
# ---> 11         business = pd.DataFrame(bis).to_numpy()
#      12         city_reviews.append(business)
#      13
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1369         """
#    1370         self._consolidate_inplace()
# -> 1371         result = self._mgr.as_array(
#    1372             transpose=self._AXIS_REVERSED, dtype=dtype, copy=copy, na_value=na_value
#    1373         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in as_array(self, transpose, dtype, copy, na_value)
#     851                     arr = arr.astype(dtype, copy=False)
#     852         else:
# --> 853             arr = self._interleave(dtype=dtype, na_value=na_value)
#     854             # The underlying data was copied within _interleave
#     855             copy = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#     891             else:
#     892                 arr = blk.get_values(dtype)
# --> 893             result[rl.indexer] = arr
#     894             itemmask[rl.indexer] = 1
#     895
#
# KeyboardInterrupt:
